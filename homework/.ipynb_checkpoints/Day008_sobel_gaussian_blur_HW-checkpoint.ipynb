# %% [markdown]
# # 作業
#
# 實作模糊與邊緣檢測
#
# - 透過 Gaussian Filter 實作模糊操作
# - 透過 Sobel Filter 實作邊緣檢測

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('data/lena.png')

# %% [markdown]
# ## 邊緣檢測

# %%
# 轉為灰階圖片
img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(14,14))
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(img_grey)

# %% [markdown]
# ### 比較 Sobel 如果在 uint8 的情況下做會 overflow 的狀況

# %%
# 對 x 方向以包含負數的資料格式 (cv2.CV_16S) 進行 Sobel 邊緣檢測
img_sobel_x = cv2.Sobel(img_grey,
                       cv2.CV_16S,
                       dx=1,
                       dy=0,
                       ksize=3)
img_sobel_x = cv2.convertScaleAbs(img_sobel_x)
img_sobel_x_uint8 = np.uint8(img_sobel_x)

plt.figure(figsize=(14,14))
plt.subplot(131)
plt.imshow(img)
plt.subplot(132)
plt.imshow(img_sobel_x)
plt.subplot(133)
plt.imshow(img_sobel_x_uint8)

# %%
#比較Sobel如果在uint8的情況下做會overflow的狀況
img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_sobel_x = cv2.Sobel(img_grey, cv2.CV_16S, dx=1, dy=0, ksize=3)
img_sobel_xx = cv2.Sobel(img_grey, cv2.CV_16S, dx=2, dy=0, ksize=3)

plt.figure(figsize=(14,14))
plt.subplot(141)
plt.imshow(img)
plt.subplot(142)
plt.imshow(img_grey)
plt.subplot(143)
plt.imshow(img_sobel_x)
plt.subplot(144)
plt.imshow(img_sobel_xx)

# %%
img_sobel_x = cv2.Sobel(img_grey, cv2.CV_16S, dx=1, dy=0, ksize=3)
img_sobel_xx = cv2.Sobel(img_grey, cv2.CV_16S, dx=2, dy=0, ksize=3)
img_sobel_x = cv2.convertScaleAbs(img_sobel_x)
img_sobel_xx = cv2.convertScaleAbs(img_sobel_x)

plt.figure(figsize=(14,14))
plt.subplot(131)
plt.imshow(img)
plt.subplot(132)
plt.imshow(img_sobel_x)
plt.subplot(133)
plt.imshow(img_sobel_xx)
